# %% [markdown]
# ## Background:
#
# We are a portfolio investment company and we make investments in the emerging markets around the world. Our company profits by investing in profitable companies, buying, holding and selling company stocks based on value investing principles.
#
# Our goal is to establish a robust intelligent system to aid our value investing efforts using stock market data. We make investment decisions and based on intrinsic value of companies and do not trade on the basis of daily market volatility. Our profit realization strategy typically involves weekly, monthly and quarterly performance of stocks we buy or hold.
#
#
# ### Data Description:
#
# You are given a set of portfolio companies trading data from emerging markets including 2020 Q1-Q2-Q3-Q4 2021 Q1 stock prices. Each company stock is provided in different sheets. Each market's operating days varies based on the country of the company and the market the stocks are exchanged. Use only 2020 data and predict with 2021 Q1 data.
#
# ### Goal(s):
#
# Predict stock price valuations on a daily, weekly and monthly basis. Recommend BUY, HOLD, SELL decisions. Maximize capital returns, minimize losses. Ideally a loss should never happen. Minimize HOLD period.
#
# ### Success Metrics:
#
# Evaluate on the basis of capital returns. Use Bollinger Bands to measure your systems effectiveness.

# %%
#Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
from datetime import datetime
import os

# %%
import keras
from keras.models import Sequential
from keras.layers import LSTM

# %%
from keras.layers import Dense

# %%
from keras.layers import Dropout

# %%
Data = pd.read_csv('C:\\Users\\Public\\Sberbank.csv')
Dataset = Data.copy()

# %%
Dataset.head()
# Out:
#         Date   Price    Open    High     Low            Vol.   Change %
# 0  31-Mar-21   291.02  294.00  294.42  290.26   47,000,000.00    -0.76%
# 1  30-Mar-21   293.25  294.86  295.72  291.50   38,810,000.00    -0.02%
# 2  29-Mar-21   293.30  289.72  294.09  289.26   43,680,000.00     0.71%
# 3  26-Mar-21   291.22  288.63  292.75  288.32   56,070,000.00     1.59%
# 4  25-Mar-21   286.66  286.50  287.03  283.85   35,220,000.00     0.30%

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1065 entries, 0 to 1064
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1065 non-null   object
#  1    Price    1065 non-null   float64
#  2    Open     1065 non-null   float64
#  3    High     1065 non-null   float64
#  4    Low      1065 non-null   float64
#  5     Vol.    1065 non-null   object
#  6   Change %  1065 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 58.4+ KB

# %%
Dataset.describe()
# Out:
#             Price         Open         High          Low
# count  1065.000000  1065.000000  1065.000000  1065.000000
# mean    215.096225   215.062911   217.526948   212.484338
# std      33.843514    33.799929    34.082267    33.513738
# min     139.000000   139.650000   142.210000   136.200000
# 25%     191.000000   191.160000   193.270000   188.200000
# 50%     216.710000   216.900000   219.180000   214.610000
# 75%     237.500000   237.500000   239.770000   235.000000
# max     293.300000   294.860000   296.070000   291.500000

# %%
Dataset.corr()
# Out:
# C:\Users\Dorcas Taiwo\AppData\Local\Temp\ipykernel_16440\497014891.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Dataset.corr()
#            Price      Open      High       Low
#  Price   1.000000  0.994382  0.997103  0.997383
#  Open    0.994382  1.000000  0.997728  0.996862
#  High    0.997103  0.997728  1.000000  0.995828
#  Low     0.997383  0.996862  0.995828  1.000000

# %%
Dataset['Date'] = pd.to_datetime(Dataset["Date"])
Dataset['Change %'] = Dataset['Change %'].str.rstrip("%").astype(float)

# %%
Dataset['Month'] = Dataset["Date"].dt.month
Dataset['WeekNum'] = Dataset["Date"].dt.week
Dataset['Quarter'] = Dataset["Date"].dt.quarter
Dataset['Year'] = Dataset["Date"].dt.year
# Out:
# C:\Users\Dorcas Taiwo\AppData\Local\Temp\ipykernel_16440\1628503213.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   Dataset['WeekNum'] = Dataset["Date"].dt.week

# %%
#Dataset['Vol.'] = Dataset['Vol.'].astype(float)

# %%
Dataset.head()
# Out:
#         Date   Price    Open    High     Low            Vol.    Change %  \
# 0 2021-03-31   291.02  294.00  294.42  290.26   47,000,000.00      -0.76
# 1 2021-03-30   293.25  294.86  295.72  291.50   38,810,000.00      -0.02
# 2 2021-03-29   293.30  289.72  294.09  289.26   43,680,000.00       0.71
# 3 2021-03-26   291.22  288.63  292.75  288.32   56,070,000.00       1.59
# 4 2021-03-25   286.66  286.50  287.03  283.85   35,220,000.00       0.30
#
#    Month  WeekNum  Quarter  Year
# 0      3       13        1  2021
# 1      3       13        1  2021
# 2      3       13        1  2021
# 3      3       12        1  2021
# 4      3       12        1  2021

# %%
month_dict = {1:'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 
              11: 'Nov', 12: 'Dec'}
Quarter_dict = {1:"Q1", 2:'Q2', 3:'Q3', 4:'Q4'}

# %%
Dataset['Month'] = Dataset.Month.map(month_dict)
Dataset['Quarter'] = Dataset.Quarter.map(Quarter_dict)

# %%
# Using + operator to combine two columns
# Example df["Period"] = df['Courses'].astype(str) +"-"+ df["Duration"]
# Example df['var3'] = df[['var1', 'var2']].astype(str).apply(lambda x: ''.join(x), axis=1)

Dataset["Quarter/Year"] = Dataset[['Quarter', 'Year']].astype(str).apply(lambda x: ''.join(x), axis=1)

# %%
Dataset.head()
# Out:
#         Date   Price    Open    High     Low            Vol.    Change %  \
# 0 2021-03-31   291.02  294.00  294.42  290.26   47,000,000.00      -0.76
# 1 2021-03-30   293.25  294.86  295.72  291.50   38,810,000.00      -0.02
# 2 2021-03-29   293.30  289.72  294.09  289.26   43,680,000.00       0.71
# 3 2021-03-26   291.22  288.63  292.75  288.32   56,070,000.00       1.59
# 4 2021-03-25   286.66  286.50  287.03  283.85   35,220,000.00       0.30
#
#   Month  WeekNum Quarter  Year Quarter/Year
# 0   Mar       13      Q1  2021       Q12021
# 1   Mar       13      Q1  2021       Q12021
# 2   Mar       13      Q1  2021       Q12021
# 3   Mar       12      Q1  2021       Q12021
# 4   Mar       12      Q1  2021       Q12021

# %%
#chart = Dataset.groupby(['Year'], as_index=False).agg({'Price':'mean','Open':'mean'})
#chart

# %% [markdown]
# ### Data Preprocessing

# %%
train = Dataset.loc[Dataset['Year'] < 2021]
test = Dataset.loc[Dataset['Year'] >= 2021]

# %%
print(train.count())
# Out:
# Date            1004
#  Price          1004
#  Open           1004
#  High           1004
#  Low            1004
#   Vol.          1004
# Change %        1004
# Month           1004
# WeekNum         1004
# Quarter         1004
# Year            1004
# Quarter/Year    1004
# dtype: int64

# %%
print(test.count())
# Out:
# Date            61
#  Price          61
#  Open           61
#  High           61
#  Low            61
#   Vol.          61
# Change %        61
# Month           61
# WeekNum         61
# Quarter         61
# Year            61
# Quarter/Year    61
# dtype: int64

# %%
train_dates = train['Date']
train_dates
# Out:
# 61     2020-12-30
# 62     2020-12-29
# 63     2020-12-28
# 64     2020-12-25
# 65     2020-12-24
#           ...
# 1060   2017-01-09
# 1061   2017-01-06
# 1062   2017-01-05
# 1063   2017-01-04
# 1064   2017-01-03
# Name: Date, Length: 1004, dtype: datetime64[ns]

# %%
test_dates = test['Date']
test_dates
# Out:
# 0    2021-03-31
# 1    2021-03-30
# 2    2021-03-29
# 3    2021-03-26
# 4    2021-03-25
#         ...
# 56   2021-01-11
# 57   2021-01-08
# 58   2021-01-06
# 59   2021-01-05
# 60   2021-01-04
# Name: Date, Length: 61, dtype: datetime64[ns]

# %%
cols = list(train)[1:5]
train_col = train[cols].astype(float)
train_col
# Out:
#        Price    Open    High     Low
# 61     271.65  272.49  274.24  270.12
# 62     272.00  275.91  276.43  271.26
# 63     274.70  270.90  275.19  269.73
# 64     270.64  269.97  271.00  268.28
# 65     269.32  271.98  272.82  267.13
# ...       ...     ...     ...     ...
# 1060   168.35  171.37  172.39  168.05
# 1061   170.69  172.40  173.75  169.50
# 1062   171.90  176.31  177.28  171.54
# 1063   175.95  178.90  179.41  174.23
# 1064   180.12  173.40  181.68  173.00
#
# [1004 rows x 4 columns]

# %%
test_col = test[cols].astype(float)
test_col
# Out:
#      Price    Open    High     Low
# 0    291.02  294.00  294.42  290.26
# 1    293.25  294.86  295.72  291.50
# 2    293.30  289.72  294.09  289.26
# 3    291.22  288.63  292.75  288.32
# 4    286.66  286.50  287.03  283.85
# ..      ...     ...     ...     ...
# 56   289.49  282.86  292.95  279.48
# 57   283.64  275.11  283.99  275.11
# 58   272.93  275.94  275.94  271.62
# 59   275.20  272.69  275.70  270.28
# 60   272.00  274.67  276.60  270.61
#
# [61 rows x 4 columns]

# %%
#test_array = (test_col.values.to_numpy())
test_array = test_col.values
test_array
# Out:
# array([[291.02, 294.  , 294.42, 290.26],
#        [293.25, 294.86, 295.72, 291.5 ],
#        [293.3 , 289.72, 294.09, 289.26],
#        [291.22, 288.63, 292.75, 288.32],
#        [286.66, 286.5 , 287.03, 283.85],
#        [285.79, 283.4 , 288.  , 282.25],
#        [282.6 , 287.56, 288.3 , 282.11],
#        [288.65, 285.  , 291.2 , 283.08],
#        [285.47, 279.  , 286.31, 278.03],
#        [279.25, 284.04, 285.79, 278.24],
#        [283.35, 292.35, 293.25, 279.6 ],
#        [292.33, 293.06, 293.88, 288.61],
#        [292.74, 286.05, 292.92, 285.28],
#        [284.93, 286.3 , 287.49, 282.82],
#        [286.  , 283.84, 286.38, 282.3 ],
#        [282.24, 285.24, 288.  , 281.  ],
#        [285.79, 278.8 , 286.38, 277.56],
#        [277.5 , 276.  , 278.98, 272.76],
#        [274.75, 278.5 , 281.96, 273.63],
#        [278.01, 281.7 , 283.83, 277.63],
#        [279.1 , 271.89, 280.  , 271.6 ],
#        [273.58, 273.  , 274.73, 271.13],
#        [270.17, 268.  , 272.49, 266.43],
#        [270.71, 273.6 , 276.48, 270.65],
#        [271.9 , 272.12, 272.75, 269.42],
#        [273.71, 270.1 , 274.46, 268.12],
#        [270.51, 271.  , 271.  , 269.02],
#        [271.34, 266.12, 272.81, 264.19],
#        [266.99, 270.35, 272.46, 266.21],
#        [270.9 , 270.99, 275.07, 267.56],
#        [270.9 , 272.3 , 272.8 , 268.27],
#        [271.81, 268.49, 271.87, 267.07],
#        [266.  , 264.  , 266.44, 258.55],
#        [264.7 , 265.5 , 266.9 , 263.75],
#        [265.9 , 269.28, 270.99, 265.2 ],
#        [268.98, 275.99, 276.29, 267.19],
#        [275.2 , 273.01, 275.58, 272.32],
#        [271.7 , 271.99, 272.57, 268.87],
#        [270.11, 263.21, 270.6 , 262.34],
#        [263.53, 264.32, 268.14, 261.05],
#        [263.15, 265.  , 268.39, 263.05],
#        [263.8 , 260.  , 264.06, 258.73],
#        [258.11, 263.77, 264.75, 257.36],
#        [265.96, 263.5 , 267.17, 261.17],
#        [265.5 , 270.07, 273.8 , 265.02],
#        [269.34, 262.7 , 269.57, 262.61],
#        [265.3 , 271.  , 273.63, 261.65],
#        [268.25, 273.  , 273.3 , 266.78],
#        [274.4 , 280.75, 281.54, 272.84],
#        [279.8 , 278.62, 282.49, 276.77],
#        [278.19, 280.98, 282.8 , 276.42],
#        [279.79, 275.72, 281.3 , 272.95],
#        [276.9 , 282.55, 286.16, 276.  ],
#        [284.79, 284.  , 286.9 , 279.06],
#        [283.78, 291.01, 292.46, 283.1 ],
#        [289.99, 290.88, 296.07, 286.7 ],
#        [289.49, 282.86, 292.95, 279.48],
#        [283.64, 275.11, 283.99, 275.11],
#        [272.93, 275.94, 275.94, 271.62],
#        [275.2 , 272.69, 275.7 , 270.28],
#        [272.  , 274.67, 276.6 , 270.61]])

# %%
#plotting 2017 - 2020 data 

dt_plot = train_col
dt_plot.plot.line()
# Out:
# <Axes: >

# %%
# Normalizing the Dataset

scalar = StandardScaler()
scalar = scalar.fit(train_col)
train_col_scaled = scalar.transform(train_col)

# %%
train_col_scaled
# Out:
# array([[ 1.94248441,  1.97441546,  1.9384188 ,  1.99325993],
#        [ 1.95375904,  2.08479034,  2.00857545,  2.03030836],
#        [ 2.04073477,  1.92310082,  1.96885205,  1.98058546],
#        ...,
#        [-1.27078583, -1.12963593, -1.16769495, -1.21045475],
#        [-1.14032222, -1.04604794, -1.0994604 , -1.12303344],
#        [-1.00599303, -1.2235514 , -1.02674094, -1.16300675]])

# %%
# Preparing and Reshaping the input into n_samples by timesteps

train_X = []
train_Y =[]

# %%
#Defining number of days we want to predict into the future and number of days used to predict the future.

n_future = 1
n_past = 7

# %%
for i in range(n_past, len(train_col_scaled) -  n_future+1):
    train_X.append(train_col_scaled[i - n_past:i, 0:train_col.shape[1]])
    train_Y.append(train_col_scaled[i + n_future-1:i + n_future, 0])

# %%
train_X, train_Y = np.array(train_X), np.array(train_Y)

# %%
train_X.shape
# Out:
# (997, 7, 4)

# %%
train_Y.shape
# Out:
# (997, 1)

# %% [markdown]
# ### Training LSTM network

# %%
model = Sequential()

# %%
model.add(LSTM(64, activation= "relu", input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences= True))
model.add(LSTM(32, activation= "relu", return_sequences= False))
model.add(Dropout(0.2))
model.add(Dense(train_Y.shape[1]))

# %%
model.compile(optimizer="adam", loss="mse")
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 7, 64)             17664
#
#  lstm_5 (LSTM)               (None, 32)                12416
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 30,113
# Trainable params: 30,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fit model

History = model.fit(train_X, train_Y, epochs=10, batch_size=16, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 3s 13ms/step - loss: 0.2213 - val_loss: 0.0560
# Epoch 2/10
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0662 - val_loss: 0.1612
# Epoch 3/10
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0539 - val_loss: 0.1256
# Epoch 4/10
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0452 - val_loss: 0.1054
# Epoch 5/10
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0384 - val_loss: 0.4285
# Epoch 6/10
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0313 - val_loss: 0.0365
# Epoch 7/10
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0320 - val_loss: 0.0942
# Epoch 8/10
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0279 - val_loss: 0.0773
# Epoch 9/10
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0252 - val_loss: 0.0378
# Epoch 10/10
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0220

# %%
plt.plot(History.history['loss'], label='Training loss')
plt.plot(History.history['val_loss'], label = 'Validation loss')
plt.legend()

# %%
#test_array = (test_col.values.to_numpy())
test_dates_array = test_dates.values
test_dates_array = np.reshape(test_dates_array, (-1,1))
test_dates_array.shape
# Out:
# (61, 1)

# %%
# Preparing test data for prediction

test_X = []
test_Y =[]

# %%
for i in range(n_past, len(test_col) -  n_future+1):
    test_X.append(test_array[i - n_past:i, 0:test_col.shape[1]])
    test_Y.append(test_array[i + n_future-1:i + n_future, 0])

# %%
test_X, test_Y = np.array(test_X), np.array(test_Y)

# %%
test_X.shape
# Out:
# (54, 7, 4)

# %%
test_Y.shape
# Out:
# (54, 1)

# %%
# for daily prediction

forecast =  model.predict(test_X)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
forecast.shape
# Out:
# (54, 1)

# %%
forecast
# Out:
# array([[249.51135],
#        [256.13184],
#        [246.01514],
#        [238.86284],
#        [244.59718],
#        [192.69257],
#        [248.28093],
#        [235.86838],
#        [233.50728],
#        [164.37756],
#        [243.34406],
#        [242.24785],
#        [237.65355],
#        [169.58041],
#        [239.01442],
#        [233.53331],
#        [227.74506],
#        [162.98547],
#        [235.79277],
#        [240.84601],
#        [228.07152],
#        [234.1399 ],
#        [237.52785],
#        [235.9103 ],
#        [162.05553],
#        [226.63637],
#        [225.23761],
#        [228.06252],
#        [234.28221],
#        [164.89346],
#        [173.84657],
#        [230.23659],
#        [219.60455],
#        [223.95708],
#        [228.14445],
#        [155.74324],
#        [230.89384],
#        [223.20036],
#        [156.17636],
#        [219.1956 ],
#        [227.9419 ],
#        [219.77492],
#        [177.37256],
#        [226.39058],
#        [165.01791],
#        [229.13121],
#        [236.36964],
#        [231.28758],
#        [170.3294 ],
#        [235.82231],
#        [159.8908 ],
#        [231.96214],
#        [232.8915 ],
#        [245.7434 ]], dtype=float32)

# %%
forecast_dates=[]
for i in range(n_past, len(test_dates_array) -  n_future+1):
    forecast_dates.append(test_dates_array[i + n_future-1:i + n_future, 0])

# %%
forecast_dates = np.array(forecast_dates)
forecast_dates.shape
# Out:
# (54, 1)

# %%
forecast_dates
# Out:
# array([['2021-03-22T00:00:00.000000000'],
#        ['2021-03-19T00:00:00.000000000'],
#        ['2021-03-18T00:00:00.000000000'],
#        ['2021-03-17T00:00:00.000000000'],
#        ['2021-03-16T00:00:00.000000000'],
#        ['2021-03-15T00:00:00.000000000'],
#        ['2021-03-12T00:00:00.000000000'],
#        ['2021-03-11T00:00:00.000000000'],
#        ['2021-03-10T00:00:00.000000000'],
#        ['2021-03-09T00:00:00.000000000'],
#        ['2021-03-05T00:00:00.000000000'],
#        ['2021-03-04T00:00:00.000000000'],
#        ['2021-03-03T00:00:00.000000000'],
#        ['2021-03-02T00:00:00.000000000'],
#        ['2021-03-01T00:00:00.000000000'],
#        ['2021-02-26T00:00:00.000000000'],
#        ['2021-02-25T00:00:00.000000000'],
#        ['2021-02-24T00:00:00.000000000'],
#        ['2021-02-22T00:00:00.000000000'],
#        ['2021-02-20T00:00:00.000000000'],
#        ['2021-02-19T00:00:00.000000000'],
#        ['2021-02-18T00:00:00.000000000'],
#        ['2021-02-17T00:00:00.000000000'],
#        ['2021-02-16T00:00:00.000000000'],
#        ['2021-02-15T00:00:00.000000000'],
#        ['2021-02-12T00:00:00.000000000'],
#        ['2021-02-11T00:00:00.000000000'],
#        ['2021-02-10T00:00:00.000000000'],
#        ['2021-02-09T00:00:00.000000000'],
#        ['2021-02-08T00:00:00.000000000'],
#        ['2021-02-05T00:00:00.000000000'],
#        ['2021-02-04T00:00:00.000000000'],
#        ['2021-02-03T00:00:00.000000000'],
#        ['2021-02-02T00:00:00.000000000'],
#        ['2021-02-01T00:00:00.000000000'],
#        ['2021-01-29T00:00:00.000000000'],
#        ['2021-01-28T00:00:00.000000000'],
#        ['2021-01-27T00:00:00.000000000'],
#        ['2021-01-26T00:00:00.000000000'],
#        ['2021-01-25T00:00:00.000000000'],
#        ['2021-01-22T00:00:00.000000000'],
#        ['2021-01-21T00:00:00.000000000'],
#        ['2021-01-20T00:00:00.000000000'],
#        ['2021-01-19T00:00:00.000000000'],
#        ['2021-01-18T00:00:00.000000000'],
#        ['2021-01-15T00:00:00.000000000'],
#        ['2021-01-14T00:00:00.000000000'],
#        ['2021-01-13T00:00:00.000000000'],
#        ['2021-01-12T00:00:00.000000000'],
#        ['2021-01-11T00:00:00.000000000'],
#        ['2021-01-08T00:00:00.000000000'],
#        ['2021-01-06T00:00:00.000000000'],
#        ['2021-01-05T00:00:00.000000000'],
#        ['2021-01-04T00:00:00.000000000']], dtype='datetime64[ns]')

# %%
#forecast_dates = pd.date_range(list(test_dates)[-1],  periods = 90, freq="1d").tolist()
#forecast_dates

# %%
#forecast_dates = np.array(test_dates, ndmin=2) #x = np.reshape(x, (-1, 1)) # Making it 1 column -> (6, 1)
#forecast_dates = np.reshape(forecast_dates, (-1,1))
#forecast_dates.shape

# %%
forecast_dates
# Out:
# array([['2021-03-22T00:00:00.000000000'],
#        ['2021-03-19T00:00:00.000000000'],
#        ['2021-03-18T00:00:00.000000000'],
#        ['2021-03-17T00:00:00.000000000'],
#        ['2021-03-16T00:00:00.000000000'],
#        ['2021-03-15T00:00:00.000000000'],
#        ['2021-03-12T00:00:00.000000000'],
#        ['2021-03-11T00:00:00.000000000'],
#        ['2021-03-10T00:00:00.000000000'],
#        ['2021-03-09T00:00:00.000000000'],
#        ['2021-03-05T00:00:00.000000000'],
#        ['2021-03-04T00:00:00.000000000'],
#        ['2021-03-03T00:00:00.000000000'],
#        ['2021-03-02T00:00:00.000000000'],
#        ['2021-03-01T00:00:00.000000000'],
#        ['2021-02-26T00:00:00.000000000'],
#        ['2021-02-25T00:00:00.000000000'],
#        ['2021-02-24T00:00:00.000000000'],
#        ['2021-02-22T00:00:00.000000000'],
#        ['2021-02-20T00:00:00.000000000'],
#        ['2021-02-19T00:00:00.000000000'],
#        ['2021-02-18T00:00:00.000000000'],
#        ['2021-02-17T00:00:00.000000000'],
#        ['2021-02-16T00:00:00.000000000'],
#        ['2021-02-15T00:00:00.000000000'],
#        ['2021-02-12T00:00:00.000000000'],
#        ['2021-02-11T00:00:00.000000000'],
#        ['2021-02-10T00:00:00.000000000'],
#        ['2021-02-09T00:00:00.000000000'],
#        ['2021-02-08T00:00:00.000000000'],
#        ['2021-02-05T00:00:00.000000000'],
#        ['2021-02-04T00:00:00.000000000'],
#        ['2021-02-03T00:00:00.000000000'],
#        ['2021-02-02T00:00:00.000000000'],
#        ['2021-02-01T00:00:00.000000000'],
#        ['2021-01-29T00:00:00.000000000'],
#        ['2021-01-28T00:00:00.000000000'],
#        ['2021-01-27T00:00:00.000000000'],
#        ['2021-01-26T00:00:00.000000000'],
#        ['2021-01-25T00:00:00.000000000'],
#        ['2021-01-22T00:00:00.000000000'],
#        ['2021-01-21T00:00:00.000000000'],
#        ['2021-01-20T00:00:00.000000000'],
#        ['2021-01-19T00:00:00.000000000'],
#        ['2021-01-18T00:00:00.000000000'],
#        ['2021-01-15T00:00:00.000000000'],
#        ['2021-01-14T00:00:00.000000000'],
#        ['2021-01-13T00:00:00.000000000'],
#        ['2021-01-12T00:00:00.000000000'],
#        ['2021-01-11T00:00:00.000000000'],
#        ['2021-01-08T00:00:00.000000000'],
#        ['2021-01-06T00:00:00.000000000'],
#        ['2021-01-05T00:00:00.000000000'],
#        ['2021-01-04T00:00:00.000000000']], dtype='datetime64[ns]')

# %%
df_price= pd.DataFrame(forecast, columns=["Price"])
df_dates= pd.DataFrame(forecast_dates, columns=["Date"])
df_forecast = pd.concat([df_dates, df_price], axis=1, join="inner")
df_forecast["Date"] = pd.to_datetime(df_forecast["Date"])
df_forecast
# Out:
#          Date       Price
# 0  2021-03-22  249.511353
# 1  2021-03-19  256.131836
# 2  2021-03-18  246.015137
# 3  2021-03-17  238.862839
# 4  2021-03-16  244.597183
# 5  2021-03-15  192.692566
# 6  2021-03-12  248.280930
# 7  2021-03-11  235.868378
# 8  2021-03-10  233.507278
# 9  2021-03-09  164.377563
# 10 2021-03-05  243.344055
# 11 2021-03-04  242.247849
# 12 2021-03-03  237.653549
# 13 2021-03-02  169.580414
# 14 2021-03-01  239.014420
# 15 2021-02-26  233.533310
# 16 2021-02-25  227.745056
# 17 2021-02-24  162.985474
# 18 2021-02-22  235.792770
# 19 2021-02-20  240.846008
# 20 2021-02-19  228.071518
# 21 2021-02-18  234.139893
# 22 2021-02-17  237.527847
# 23 2021-02-16  235.910294
# 24 2021-02-15  162.055527
# 25 2021-02-12  226.636368
# 26 2021-02-11  225.237610
# 27 2021-02-10  228.062515
# 28 2021-02-09  234.282211
# 29 2021-02-08  164.893463
# 30 2021-02-05  173.846573
# 31 2021-02-04  230.236588
# 32 2021-02-03  219.604553
# 33 2021-02-02  223.957077
# 34 2021-02-01  228.144455
# 35 2021-01-29  155.743240
# 36 2021-01-28  230.893845
# 37 2021-01-27  223.200363
# 38 2021-01-26  156.176361
# 39 2021-01-25  219.195602
# 40 2021-01-22  227.941895
# 41 2021-01-21  219.774918
# 42 2021-01-20  177.372559
# 43 2021-01-19  226.390579
# 44 2021-01-18  165.017914
# 45 2021-01-15  229.131210
# 46 2021-01-14  236.369644
# 47 2021-01-13  231.287582
# 48 2021-01-12  170.329407
# 49 2021-01-11  235.822311
# 50 2021-01-08  159.890793
# 51 2021-01-06  231.962143
# 52 2021-01-05  232.891495
# 53 2021-01-04  245.743393

# %%
Dataset.head()
# Out:
#         Date   Price    Open    High     Low            Vol.    Change %  \
# 0 2021-03-31   291.02  294.00  294.42  290.26   47,000,000.00      -0.76
# 1 2021-03-30   293.25  294.86  295.72  291.50   38,810,000.00      -0.02
# 2 2021-03-29   293.30  289.72  294.09  289.26   43,680,000.00       0.71
# 3 2021-03-26   291.22  288.63  292.75  288.32   56,070,000.00       1.59
# 4 2021-03-25   286.66  286.50  287.03  283.85   35,220,000.00       0.30
#
#   Month  WeekNum Quarter  Year Quarter/Year
# 0   Mar       13      Q1  2021       Q12021
# 1   Mar       13      Q1  2021       Q12021
# 2   Mar       13      Q1  2021       Q12021
# 3   Mar       12      Q1  2021       Q12021
# 4   Mar       12      Q1  2021       Q12021

# %%
train.head()
# Out:
#          Date   Price    Open    High     Low            Vol.    Change %  \
# 61 2020-12-30   271.65  272.49  274.24  270.12   31,530,000.00      -0.13
# 62 2020-12-29   272.00  275.91  276.43  271.26   39,020,000.00      -0.98
# 63 2020-12-28   274.70  270.90  275.19  269.73   39,040,000.00       1.50
# 64 2020-12-25   270.64  269.97  271.00  268.28   11,990,000.00       0.49
# 65 2020-12-24   269.32  271.98  272.82  267.13   42,610,000.00      -0.29
#
#    Month  WeekNum Quarter  Year Quarter/Year
# 61   Dec       53      Q4  2020       Q42020
# 62   Dec       53      Q4  2020       Q42020
# 63   Dec       53      Q4  2020       Q42020
# 64   Dec       52      Q4  2020       Q42020
# 65   Dec       52      Q4  2020       Q42020

# %%
Original = train[["Date", "Price"]].copy()
Original["Date"]= pd.to_datetime(Original["Date"])
Original.head()

# %%
train.reset_index(drop=True)
# Out:
#            Date   Price    Open    High     Low            Vol.    Change %  \
# 0    2020-12-30   271.65  272.49  274.24  270.12   31,530,000.00      -0.13
# 1    2020-12-29   272.00  275.91  276.43  271.26   39,020,000.00      -0.98
# 2    2020-12-28   274.70  270.90  275.19  269.73   39,040,000.00       1.50
# 3    2020-12-25   270.64  269.97  271.00  268.28   11,990,000.00       0.49
# 4    2020-12-24   269.32  271.98  272.82  267.13   42,610,000.00      -0.29
# ...         ...      ...     ...     ...     ...              ...       ...
# 999  2017-01-09   168.35  171.37  172.39  168.05   35,187,382.00      -1.37
# 1000 2017-01-06   170.69  172.40  173.75  169.50   35,415,591.00      -0.70
# 1001 2017-01-05   171.90  176.31  177.28  171.54   35,093,060.00      -2.30
# 1002 2017-01-04   175.95  178.90  179.41  174.23   41,400,772.00      -2.32
# 1003 2017-01-03   180.12  173.40  181.68  173.00   53,895,668.00       3.97
#
#      Month  WeekNum Quarter  Year Quarter/Year
# 0      Dec       53      Q4  2020       Q42020
# 1      Dec       53      Q4  2020       Q42020
# 2      Dec       53      Q4  2020       Q42020
# 3      Dec       52      Q4  2020       Q42020
# 4      Dec       52      Q4  2020       Q42020
# ...    ...      ...     ...   ...          ...
# 999    Jan        2      Q1  2017       Q12017
# 1000   Jan        1      Q1  2017       Q12017
# 1001   Jan        1      Q1  2017       Q12017
# 1002   Jan        1      Q1  2017       Q12017
# 1003   Jan        1      Q1  2017       Q12017
#
# [1004 rows x 12 columns]

# %%
sns.lineplot(train['Date'], train['Price'])
sns.lineplot(df_forecast['Date'], df_forecast['Price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Users\Dorcas\anaconda3\envs\Myevn\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\Users\Dorcas\anaconda3\envs\Myevn\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Users\Dorcas\anaconda3\envs\Myevn\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[254], line 1
# ----> 1 sns.lineplot(train['Date'], train['Price'])
#       2 sns.lineplot(df_forecast['Date'], df_forecast['Price'])
#
# File C:\Users\Dorcas\anaconda3\envs\Myevn\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File C:\Users\Dorcas\anaconda3\envs\Myevn\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Price'
